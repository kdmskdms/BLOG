# %%
import pandas as pd

url = "https://statiz.sporki.com/stats/?m=total&m2=pitching"
tables = pd.read_html(url)
print(len(tables),"개의 테이블이 있습니다")
df_list = pd.read_html(url)
# Out:
# 1 개의 테이블이 있습니다

# %%
df=df_list[0]

# %%
df
# Out:
#    Rank Name   Team     정렬▼     G   GS    GR   GF    W    L  ...    SO ROE  \
#    Rank Name   Team     WAR     G   GS    GR   GF    W    L  ...    SO ROE
# 0     1  선동열   95해P  101.67   367  109   258  308  146   40  ...  1698 NaN
# 1     2  임창용   18해P   75.31   760  140   620  458  130   86  ...  1474 NaN
# 2     3  송진우   09빙P   71.42   672  377   295  252  210  153  ...  2048 NaN
# 3     4  양현종  23+KP   64.70   484  383   101   37  168  113  ...  1947 NaN
# 4     5  정대현   16SP   63.44   662    0   662  229   46   29  ...   559 NaN
# 5     6  이강철   05해P   62.61   602  265   337  193  152  112  ...  1751 NaN
# 6     7  김광현  24+SP   61.88   357  335    22   17  159   88  ...  1734 NaN
# 7     8  오승환  24+삼P   61.20   670    1   669  581   42   24  ...   817 NaN
# 8     9  김용수   00MP   61.17   613  129   484  439  126   89  ...  1145 NaN
# 9    10  김현욱   04삼P   57.69   519    2   517  123   71   31  ...   736 NaN
# ...

# %%
# 두 번째 레벨의 컬럼명만 선택하여 사용
df.columns = df.columns.get_level_values(0)

# %%
df
# Out:
#     Rank Name   Team     WAR     G   GS    GR   GF    W    L  ...    SO  ROE  \
# 0      1  선동열   95해P  101.67   367  109   258  308  146   40  ...  1698  NaN
# 1      2  임창용   18해P   75.31   760  140   620  458  130   86  ...  1474  NaN
# 2      3  송진우   09빙P   71.42   672  377   295  252  210  153  ...  2048  NaN
# 3      4  양현종  23+KP   64.70   484  383   101   37  168  113  ...  1947  NaN
# 4      5  정대현   16SP   63.44   662    0   662  229   46   29  ...   559  NaN
# 5      6  이강철   05해P   62.61   602  265   337  193  152  112  ...  1751  NaN
# 6      7  김광현  24+SP   61.88   357  335    22   17  159   88  ...  1734  NaN
# 7      8  오승환  24+삼P   61.20   670    1   669  581   42   24  ...   817  NaN
# 8      9  김용수   00MP   61.17   613  129   484  439  126   89  ...  1145  NaN
# 9     10  김현욱   04삼P   57.69   519    2   517  123   71   31  ...   736  NaN
# 10    11  정민철   09빙P   50.72   393  370    23   77  161  128  ...  1661  NaN
# ...

# %%
columns_to_drop = ['Rank', '2B', '3B','ROE','WAR▼']
df = df.drop(columns=columns_to_drop)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    50 non-null     object
#  1   Team    50 non-null     object
#  2   WAR     50 non-null     float64
#  3   G       50 non-null     int64
#  4   GS      50 non-null     int64
#  5   GR      50 non-null     int64
#  6   GF      50 non-null     int64
#  7   W       50 non-null     int64
#  8   L       50 non-null     int64
#  9   S       50 non-null     int64
#  10  HD      50 non-null     int64
#  11  IP      50 non-null     float64
#  12  ER      50 non-null     int64
#  13  R       50 non-null     int64
#  14  rRA     50 non-null     float64
#  15  TBF     50 non-null     int64
#  16  H       50 non-null     int64
#  17  HR      50 non-null     int64
#  18  BB      50 non-null     int64
#  19  HP      50 non-null     int64
#  20  IB      50 non-null     int64
# ...

# %%
df.head(30)
# Out:
#    Name   Team     WAR     G   GS    GR   GF    W    L    S  ...   HP  IB  \
# 0   선동열   95해P  101.67   367  109   258  308  146   40  132  ...   62  14
# 1   임창용   18해P   75.31   760  140   620  458  130   86  258  ...  152  44
# 2   송진우   09빙P   71.42   672  377   295  252  210  153  103  ...  117  55
# 3   양현종  23+KP   64.70   484  383   101   37  168  113    0  ...   51   6
# 4   정대현   16SP   63.44   662    0   662  229   46   29  106  ...   49  57
# 5   이강철   05해P   62.61   602  265   337  193  152  112   53  ...  189  56
# 6   김광현  24+SP   61.88   357  335    22   17  159   88    0  ...   46  13
# 7   오승환  24+삼P   61.20   670    1   669  581   42   24  401  ...   16  15
# 8   김용수   00MP   61.17   613  129   484  439  126   89  227  ...   61  55
# 9   김현욱   04삼P   57.69   519    2   517  123   71   31   22  ...   59  25
# 10  정민철   09빙P   50.72   393  370    23   77  161  128   10  ...   93  24
# 11  조웅천   09태P   48.64   813   13   800  313   64   54   98  ...   65  55
# ...

# %%
url = "https://statiz.sporki.com/player/?m=year&p_no=13934"
tables = pd.read_html(url)
print(len(tables),"개의 테이블이 있습니다")
df_list = pd.read_html(url)
df_list[0]
# Out:
# 1 개의 테이블이 있습니다
#    Year  Team   Age Pos.    G   GS GR GF   W   L  ...   SO ROE BK  WP   ERA  \
#    Year  Team   Age Pos.    G   GS GR GF   W   L  ...   SO ROE BK  WP   ERA
#    Year Total Total Pos.    G   GS GR GF   W   L  ...   SO ROE BK  WP   ERA
#    Year Total Total Pos.    G   GS GR GF   W   L  ...   SO ROE BK  WP   ERA
# 0  2019    LG    30    P   29   29  0  0  14  12  ...  126   8  0  12  2.55
# 1  2020    LG    31    P   28   28  0  1  15   7  ...  134   5  0   4  3.32
# 2  2021    LG    32    P   30   30  0  0  13   8  ...  142   7  1   7  3.15
# 3  2022    LG    33    P   27   27  0  0  16   4  ...  153   5  0   3  2.54
# 4  2023    LG    34    P   30   30  0  0  10   7  ...  129   7  0   6  3.83
# 5   5시즌    통산    통산    P  144  144  0  1  68  38  ...  684  32  1  32  3.08
#
#     RA9  rRA9    FIP  WHIP    WAR
#     RA9  rRA9    FIP  WHIP    WAR
#     RA9  rRA9    FIP  WHIP    WAR
#     RA9  rRA9    FIP  WHIP    WAR
# 0  3.49  3.49   3.50  1.14   4.03
# ...

# %%
df2=df_list[0]

# %%
# 두 번째 레벨의 컬럼명만 선택하여 사용
df2.columns = df2.columns.get_level_values(1)

# %%
df2
# Out:
#    Year Team Age Pos.    G   GS  GR  GF   W   L  ...   SO  ROE  BK  WP   ERA  \
# 0  2019   LG  30    P   29   29   0   0  14  12  ...  126    8   0  12  2.55
# 1  2020   LG  31    P   28   28   0   1  15   7  ...  134    5   0   4  3.32
# 2  2021   LG  32    P   30   30   0   0  13   8  ...  142    7   1   7  3.15
# 3  2022   LG  33    P   27   27   0   0  16   4  ...  153    5   0   3  2.54
# 4  2023   LG  34    P   30   30   0   0  10   7  ...  129    7   0   6  3.83
# 5   5시즌   통산  통산    P  144  144   0   1  68  38  ...  684   32   1  32  3.08
#
#     RA9  rRA9    FIP  WHIP    WAR
# 0  3.49  3.49   3.50  1.14   4.03
# 1  3.48  3.48   4.07  1.15   5.57
# 2  3.25  3.21   3.76  1.24   5.63
# 3  2.71  2.71   2.89  1.08   5.26
# 4  4.38  4.13   3.49  1.24   3.41
# 5  3.47  3.41  17.72  1.17  23.90
#
# [6 rows x 34 columns]
