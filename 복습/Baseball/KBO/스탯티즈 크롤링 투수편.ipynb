# %%
import pandas as pd

url = "http://www.statiz.co.kr/stat.php?opt=0&sopt=0&re=1&ys=1982&ye=2023&se=0&te=&tm=&ty=0&qu=auto&po=0&as=&ae=&hi=&un=&pl=&da=1&o1=WAR&o2=OutCount&de=1&lr=1&tr=&cv=&ml=1&sn=30&si=&cn="
tables = pd.read_html(url)
print(len(tables),"개의 테이블이 있습니다")
df_list = pd.read_html(url)
# Out:
# 3 개의 테이블이 있습니다

# %%
df = df_list[0]

# %%
df
# Out:
#     팀 기록                                              ...                      \
#        순     이름   팀     정렬   출장  완투  완봉   선발   승   패  ... Unnamed: 40_level_1
#        순     이름   팀    WAR   출장  완투  완봉   선발   승   패  ... Unnamed: 40_level_2
# 0      1     해태  91  34.99  276  34  10  126  79  42  ...                 NaN
# 1      2     현대  00  33.47  431   5   2  133  91  40  ...                 NaN
# 2      3     SK  09  31.66  556   2   0  133  80  47  ...                 NaN
# 3      4     해태  95  31.38  316  15   4  126  64  58  ...                 NaN
# 4      5    KIA  09  31.12  480   4   0  133  81  48  ...                 NaN
# ..   ...    ...  ..    ...  ...  ..  ..  ...  ..  ..  ...                 ...
# 406    순     이름   팀     정렬   출장  완투  완봉   선발   승   패  ...                 NaN
# 407    순     이름   팀    WAR   출장  완투  완봉   선발   승   패  ...                 NaN
# 408  341     한화  22   6.62  749   1   0  144  46  95  ...                 NaN
# 409  342  삼미/청보  85   5.24  232  37   3  110  39  70  ...                 NaN
# 410  343     삼미  82  -0.16  200   7   0   80  15  65  ...                 NaN
#
#                                                                  \
#     Unnamed: 41_level_1 Unnamed: 42_level_1 Unnamed: 43_level_1
#     Unnamed: 41_level_2 Unnamed: 42_level_2 Unnamed: 43_level_2
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
# ..                  ...                 ...                 ...
# 406                 NaN                 NaN                 NaN
# 407                 NaN                 NaN                 NaN
# 408                 NaN                 NaN                 NaN
# 409                 NaN                 NaN                 NaN
# 410                 NaN                 NaN                 NaN
#
#                                                                  \
#     Unnamed: 44_level_1 Unnamed: 45_level_1 Unnamed: 46_level_1
#     Unnamed: 44_level_2 Unnamed: 45_level_2 Unnamed: 46_level_2
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
# ..                  ...                 ...                 ...
# 406                 NaN                 NaN                 NaN
# 407                 NaN                 NaN                 NaN
# 408                 NaN                 NaN                 NaN
# 409                 NaN                 NaN                 NaN
# 410                 NaN                 NaN                 NaN
#
#
#     Unnamed: 47_level_1 Unnamed: 48_level_1 Unnamed: 49_level_1
#     Unnamed: 47_level_2 Unnamed: 48_level_2 Unnamed: 49_level_2
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
# ..                  ...                 ...                 ...
# 406                 NaN                 NaN                 NaN
# 407                 NaN                 NaN                 NaN
# 408                 NaN                 NaN                 NaN
# 409                 NaN                 NaN                 NaN
# 410                 NaN                 NaN                 NaN
#
# [411 rows x 50 columns]

# %%
# 두 번째 레벨의 컬럼명만 선택하여 사용
df.columns = df.columns.get_level_values(2)

# %%
#30번째 행 다 삭제 진행
index_of_column_30 = 30
df = df.iloc[:, :index_of_column_30 + 1]

# %%
df
# Out:
#        순     이름   팀    WAR   출장  완투  완봉   선발   승   패  ...  고4  사구    삼진  보크  \
# 0      1     해태  91  34.99  276  34  10  126  79  42  ...  11  53   776   6
# 1      2     현대  00  33.47  431   5   2  133  91  40  ...  10  34   997   4
# 2      3     SK  09  31.66  556   2   0  133  80  47  ...  33  54  1032   3
# 3      4     해태  95  31.38  316  15   4  126  64  58  ...  19  75   872   3
# 4      5    KIA  09  31.12  480   4   0  133  81  48  ...  22  83   893   2
# ..   ...    ...  ..    ...  ...  ..  ..  ...  ..  ..  ...  ..  ..   ...  ..
# 406    순     이름   팀     정렬   출장  완투  완봉   선발   승   패  ...  고4  사구    삼진  보크
# 407    순     이름   팀    WAR   출장  완투  완봉   선발   승   패  ...  고4  사구    삼진  보크
# 408  341     한화  22   6.62  749   1   0  144  46  95  ...  39  83   974   4
# 409  342  삼미/청보  85   5.24  232  37   3  110  39  70  ...  13  60   393   6
# 410  343     삼미  82  -0.16  200   7   0   80  15  65  ...  11  50   175   7
#
#      폭투   ERA   FIP  WHIP   ERA+   FIP+
# 0    21  2.89  3.13  1.11  137.4  127.0
# 1    46  3.64  3.72  1.31  124.2  121.5
# 2    68  3.67  4.22  1.37  129.1  112.3
# 3    44  3.06  3.27  1.16  123.0  115.5
# 4    22  3.92  4.13  1.35  120.4  114.3
# ..   ..   ...   ...   ...    ...    ...
# 406  폭투    비율    비율    비율     비율     비율
# 407  폭투   ERA   FIP  WHIP   ERA+   FIP+
# 408  65  4.82  4.48  1.51   84.0   91.1
# 409  33  4.88  4.35  1.56   74.7   83.7
# 410  22  6.14  5.15  1.71   65.5   78.2
#
# [411 rows x 31 columns]

# %%
# df 이름 항목에서 이름이 있는 행 제거
df = df[~df['이름'].str.contains('이름')]
#다음 해당하는 컬럼 삭제
columns_to_drop = ['순', '2타', '3타','WAR']
df = df.drop(columns=columns_to_drop)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 343 entries, 0 to 410
# Data columns (total 27 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      343 non-null    object
#  1   팀       343 non-null    object
#  2   출장      343 non-null    object
#  3   완투      343 non-null    object
#  4   완봉      343 non-null    object
#  5   선발      343 non-null    object
#  6   승       343 non-null    object
#  7   패       343 non-null    object
#  8   세       343 non-null    object
#  9   홀드      343 non-null    object
#  10  이닝      343 non-null    object
#  11  실점      343 non-null    object
#  12  자책      343 non-null    object
#  13  타자      343 non-null    object
#  14  안타      343 non-null    object
#  15  홈런      343 non-null    object
#  16  볼넷      343 non-null    object
#  17  고4      343 non-null    object
#  18  사구      343 non-null    object
#  19  삼진      343 non-null    object
#  20  보크      343 non-null    object
#  21  폭투      343 non-null    object
#  22  ERA     343 non-null    object
#  23  FIP     343 non-null    object
#  24  WHIP    343 non-null    object
#  25  ERA+    343 non-null    object
#  26  FIP+    343 non-null    object
# dtypes: object(27)
# memory usage: 75.0+ KB

# %%
# 팀 이름을 제외한 나머지 열은 int로 변환
int_columns = df.columns.difference(['이름','이닝', 'ERA', 'FIP', 'WHIP', 'ERA+','FIP+'])
df[int_columns] = df[int_columns].astype(int)
float_columns = ['이닝', 'ERA', 'FIP', 'WHIP', 'ERA+','FIP+']
df[float_columns] = df[float_columns].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 343 entries, 0 to 410
# Data columns (total 27 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      343 non-null    object
#  1   팀       343 non-null    int32
#  2   출장      343 non-null    int32
#  3   완투      343 non-null    int32
#  4   완봉      343 non-null    int32
#  5   선발      343 non-null    int32
#  6   승       343 non-null    int32
#  7   패       343 non-null    int32
#  8   세       343 non-null    int32
#  9   홀드      343 non-null    int32
#  10  이닝      343 non-null    float64
#  11  실점      343 non-null    int32
#  12  자책      343 non-null    int32
#  13  타자      343 non-null    int32
#  14  안타      343 non-null    int32
#  15  홈런      343 non-null    int32
#  16  볼넷      343 non-null    int32
#  17  고4      343 non-null    int32
#  18  사구      343 non-null    int32
#  19  삼진      343 non-null    int32
#  20  보크      343 non-null    int32
#  21  폭투      343 non-null    int32
#  22  ERA     343 non-null    float64
#  23  FIP     343 non-null    float64
#  24  WHIP    343 non-null    float64
#  25  ERA+    343 non-null    float64
#  26  FIP+    343 non-null    float64
# dtypes: float64(6), int32(20), object(1)
# memory usage: 48.2+ KB

# %%
# 2번쨰 컬럼부터 진행(object 제거)
df = df.iloc[:,1:]

# %%
df
# Out:
#       팀   출장  완투  완봉   선발   승   패   세  홀드      이닝  ...  고4   사구    삼진  보크  폭투  \
# 0    91  276  34  10  126  79  42  28   0  1130.2  ...  11   53   776   6  21
# 1     0  431   5   2  133  91  40  51  30  1189.2  ...  10   34   997   4  46
# 2     9  556   2   0  133  80  47  33  34  1213.0  ...  33   54  1032   3  68
# 3    95  316  15   4  126  64  58  40   0  1127.2  ...  19   75   872   3  44
# 4     9  480   4   0  133  81  48  38  36  1199.0  ...  22   83   893   2  22
# ..   ..  ...  ..  ..  ...  ..  ..  ..  ..     ...  ...  ..  ...   ...  ..  ..
# 404   0  523   1   0  133  44  86  21   9  1165.2  ...  38   76   718   2  48
# 405  17  613   1   0  144  55  84  27  34  1281.1  ...  15  118  1063   4  74
# 408  22  749   1   0  144  46  95  25  81  1268.1  ...  39   83   974   4  65
# 409  85  232  37   3  110  39  70  15   0   977.2  ...  13   60   393   6  33
# 410  82  200   7   0   80  15  65   5   0   701.2  ...  11   50   175   7  22
#
#       ERA   FIP  WHIP   ERA+   FIP+
# 0    2.89  3.13  1.11  137.4  127.0
# 1    3.64  3.72  1.31  124.2  121.5
# 2    3.67  4.22  1.37  129.1  112.3
# 3    3.06  3.27  1.16  123.0  115.5
# 4    3.92  4.13  1.35  120.4  114.3
# ..    ...   ...   ...    ...    ...
# 404  5.99  5.55  1.65   77.5   83.7
# 405  5.90  5.50  1.63   86.0   91.7
# 408  4.82  4.48  1.51   84.0   91.1
# 409  4.88  4.35  1.56   74.7   83.7
# 410  6.14  5.15  1.71   65.5   78.2
#
# [343 rows x 26 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 득점과 다른 열 간의 상관관계만 추출
corr_with_score = df.corr()['실점'].drop('실점')

# 상관관계 크기를 기준으로 내림차순 정렬
sorted_corr = corr_with_score.sort_values(ascending=False)

# 폰트 설정
plt.rc('font', family='Malgun Gothic')

# 히트맵 생성
plt.figure(figsize=(4, 7))
sns.heatmap(pd.DataFrame(sorted_corr), annot=True, cmap='coolwarm', fmt=".2f", cbar=False)
plt.title('Correlation Heatmap with 실점')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 득점과 다른 열 간의 상관관계만 추출
corr_with_score = df.corr()['삼진'].drop('삼진')

# 상관관계 크기를 기준으로 내림차순 정렬
sorted_corr = corr_with_score.sort_values(ascending=False)

# 폰트 설정
plt.rc('font', family='Malgun Gothic')

# 히트맵 생성
plt.figure(figsize=(4, 7))
sns.heatmap(pd.DataFrame(sorted_corr), annot=True, cmap='coolwarm', fmt=".2f", cbar=False)
plt.title('Correlation Heatmap with 삼진')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 득점과 다른 열 간의 상관관계만 추출
corr_with_score = df.corr()['승'].drop('승')

# 상관관계 크기를 기준으로 내림차순 정렬
sorted_corr = corr_with_score.sort_values(ascending=False)

# 폰트 설정
plt.rc('font', family='Malgun Gothic')

# 히트맵 생성
plt.figure(figsize=(4, 7))
sns.heatmap(pd.DataFrame(sorted_corr), annot=True, cmap='coolwarm', fmt=".2f", cbar=False)
plt.title('Correlation Heatmap with 승')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 득점과 다른 열 간의 상관관계만 추출
corr_with_score = df.corr()['패'].drop('패')

# 상관관계 크기를 기준으로 내림차순 정렬
sorted_corr = corr_with_score.sort_values(ascending=False)

# 폰트 설정
plt.rc('font', family='Malgun Gothic')

# 히트맵 생성
plt.figure(figsize=(4, 7))
sns.heatmap(pd.DataFrame(sorted_corr), annot=True, cmap='coolwarm', fmt=".2f", cbar=False)
plt.title('Correlation Heatmap with 패')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 득점과 다른 열 간의 상관관계만 추출
corr_with_score = df.corr()['ERA'].drop('ERA')

# 상관관계 크기를 기준으로 내림차순 정렬
sorted_corr = corr_with_score.sort_values(ascending=False)

# 폰트 설정
plt.rc('font', family='Malgun Gothic')

# 히트맵 생성
plt.figure(figsize=(4, 7))
sns.heatmap(pd.DataFrame(sorted_corr), annot=True, cmap='coolwarm', fmt=".2f", cbar=False)
plt.title('Correlation Heatmap with ERA')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 득점과 다른 열 간의 상관관계만 추출
corr_with_score = df.corr()['이닝'].drop('이닝')

# 상관관계 크기를 기준으로 내림차순 정렬
sorted_corr = corr_with_score.sort_values(ascending=False)

# 폰트 설정
plt.rc('font', family='Malgun Gothic')

# 히트맵 생성
plt.figure(figsize=(4, 7))
sns.heatmap(pd.DataFrame(sorted_corr), annot=True, cmap='coolwarm', fmt=".2f", cbar=False)
plt.title('Correlation Heatmap with 이닝')
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 상관 행렬 계산
corr_matrix = df.corr()

# 폰트 설정
plt.rc('font', family='Malgun Gothic')

# 숨길 상관관계 값 설정
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
mask[np.tril_indices_from(mask)] = False

# 히트맵 생성
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", mask=mask)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# c:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# c:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 폰트 설정
plt.rc('font', family='Malgun Gothic')

# 선택한 항목들
selected_columns = ['승', '패', '세', '이닝', '자책', '안타', '홈런', '볼넷', '삼진', 'ERA', 'FIP', 'WHIP', 'ERA+', 'FIP+', '홀드', '타자']

# 색상 설정
colors = ['red', 'orange', 'yellow', 'green', 'blue', 'purple', 'brown', 'pink', 'gray', 'cyan', 'magenta', 'lime', 'teal', 'lavender', 'coral', 'lightblue']

# 4행 4열의 그리드 생성
fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(10, 10))

# 각 항목을 그리드에 순서대로 표시
for i, column in enumerate(selected_columns):
    row = i // 4  # 현재 항목의 행 인덱스
    col = i % 4   # 현재 항목의 열 인덱스
    sns.scatterplot(x='실점', y=column, data=df, color=colors[i], ax=axs[row, col])
    axs[row, col].set_xlabel('실점')
    axs[row, col].set_ylabel(column)
    axs[row, col].grid(True)

# 그리드 간의 간격 조절
plt.tight_layout()
plt.show()
