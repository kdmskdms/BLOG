# %%
import pandas as pd
import csv
import openpyxl

# %%
df1 = pd.read_excel('Summary (3).xlsx')
df1
# Out:
#               Player    Season Team S/C  GP  GS   W   L   T  OT  ...  Svs  \
# 0      Samuel Ersson  20232024  PHI   L  40  38  20  14  --   5  ...  868
# 1    Pyotr Kochetkov  20232024  CAR   L  36  34  19  12  --   3  ...  826
# 2         Joel Hofer  20232024  STL   L  25  22  12  11  --   0  ...  647
# 3       Lukas Dostal  20232024  ANA   L  34  28  10  19  --   1  ...  913
# 4        Joseph Woll  20232024  TOR   L  18  16   9   7  --   1  ...  523
# 5          Nico Daws  20232024  NJD   L  21  20   9  11  --   0  ...  508
# 6         Devon Levi  20232024  BUF   L  21  20   9   8  --   2  ...  540
# 7     Daniil Tarasov  20232024  CBJ   L  20  19   7   9  --   3  ...  590
# 8     Cayden Primeau  20232024  MTL   L  16  15   6   7  --   2  ...  437
# 9     Justus Annunen  20232024  COL   L   8   8   5   2  --   1  ...  239
# 10    Ivan Prosvetov  20232024  COL   L  11   8   4   3  --   1  ...  222
# 11   Arvid Soderblom  20232024  CHI   L  26  24   4  19  --   1  ...  659
# 12       Dustin Wolf  20232024  CGY   L  10   8   3   4  --   1  ...  253
# 13       Matt Murray  20232024  DAL   L   1   1   1   0  --   0  ...   23
# 14  Yaroslav Askarov  20232024  NSH   R   2   1   1   0  --   0  ...   33
# 15       Jet Greaves  20232024  CBJ   L   3   3   1   2  --   0  ...   97
# 16       Jiri Patera  20232024  VGK   L   5   4   1   3  --   0  ...  145
# 17      Mads Sogaard  20232024  OTT   L   6   5   1   3  --   0  ...  116
# 18     Magnus Chrona  20232024  SJS   L   9   8   1   6  --   1  ...  225
# 19      Yaniv Perets  20232024  CAR   L   1   0   0   0  --   0  ...    1
# 20     Matt Villalta  20232024  ARI   L   2   1   0   1  --   0  ...   24
# 21  Jesper Wallstedt  20232024  MIN   L   1   1   0   1  --   0  ...   27
#
#      GA    Sv%   GAA      TOI SO  G  A  P  PIM
# 0    99  0.898  2.68  2220:14  3  0  0  0    2
# 1    79  0.913  2.36  2009:00  3  0  0  0    6
# 2    61  0.915  2.76  1326:45  1  0  0  0    2
# 3   103  0.899  3.58  1724:28  0  0  0  0    6
# 4    51  0.911  2.89  1058:12  0  0  0  0    0
# 5    60  0.894  3.15  1144:03  0  0  1  1    0
# 6    64  0.894  3.24  1184:40  0  0  0  0    0
# 7    63  0.904  3.20  1181:02  0  0  0  0    0
# 8    46  0.905  2.97   929:07  2  0  2  2    2
# 9    19  0.926  2.38   479:34  2  0  0  0    0
# 10   26  0.895  3.16   494:11  0  0  0  0    0
# 11   93  0.877  4.02  1388:51  0  0  0  0    0
# 12   29  0.897  3.25   534:36  0  0  0  0    0
# 13    0  1.000  0.00    60:00  1  0  0  0    0
# 14    2  0.943  1.47    81:40  0  0  0  0    0
# 15   10  0.907  3.38   177:39  0  0  0  0    0
# 16   16  0.901  3.75   256:06  0  0  0  0    0
# 17   19  0.859  4.05   281:34  0  0  0  0    0
# 18   37  0.859  4.71   471:15  0  0  0  0    0
# 19    0  1.000  0.00    12:46  0  0  0  0    0
# 20    5  0.828  4.17    71:58  0  0  0  0    0
# 21    7  0.794  7.00    60:00  0  0  0  0    0
#
# [22 rows x 21 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  22 non-null     object
#  1   Season  22 non-null     int64
#  2   Team    22 non-null     object
#  3   S/C     22 non-null     object
#  4   GP      22 non-null     int64
#  5   GS      22 non-null     int64
#  6   W       22 non-null     int64
#  7   L       22 non-null     int64
#  8   T       22 non-null     object
#  9   OT      22 non-null     int64
#  10  SA      22 non-null     object
#  11  Svs     22 non-null     int64
#  12  GA      22 non-null     int64
#  13  Sv%     22 non-null     float64
#  14  GAA     22 non-null     float64
#  15  TOI     22 non-null     object
#  16  SO      22 non-null     int64
#  17  G       22 non-null     int64
#  18  A       22 non-null     int64
#  19  P       22 non-null     int64
#  20  PIM     22 non-null     int64
# dtypes: float64(2), int64(13), object(6)
# memory usage: 3.7+ KB

# %%
df1 = df1[df1['GP'] >=20]

# %%
df1
# Out:
#              Player    Season Team S/C  GP  GS   W   L   T  OT  ...  Svs   GA  \
# 0     Samuel Ersson  20232024  PHI   L  40  38  20  14  --   5  ...  868   99
# 1   Pyotr Kochetkov  20232024  CAR   L  36  34  19  12  --   3  ...  826   79
# 2        Joel Hofer  20232024  STL   L  25  22  12  11  --   0  ...  647   61
# 3      Lukas Dostal  20232024  ANA   L  34  28  10  19  --   1  ...  913  103
# 5         Nico Daws  20232024  NJD   L  21  20   9  11  --   0  ...  508   60
# 6        Devon Levi  20232024  BUF   L  21  20   9   8  --   2  ...  540   64
# 7    Daniil Tarasov  20232024  CBJ   L  20  19   7   9  --   3  ...  590   63
# 11  Arvid Soderblom  20232024  CHI   L  26  24   4  19  --   1  ...  659   93
#
#       Sv%   GAA      TOI SO  G  A  P  PIM
# 0   0.898  2.68  2220:14  3  0  0  0    2
# 1   0.913  2.36  2009:00  3  0  0  0    6
# 2   0.915  2.76  1326:45  1  0  0  0    2
# 3   0.899  3.58  1724:28  0  0  0  0    6
# 5   0.894  3.15  1144:03  0  0  1  1    0
# 6   0.894  3.24  1184:40  0  0  0  0    0
# 7   0.904  3.20  1181:02  0  0  0  0    0
# 11  0.877  4.02  1388:51  0  0  0  0    0
#
# [8 rows x 21 columns]

# %%
df_sorted = df1.sort_values(by='GP', ascending=False)
df_sorted
# Out:
#              Player    Season Team S/C  GP  GS   W   L   T  OT  ...  Svs   GA  \
# 0     Samuel Ersson  20232024  PHI   L  40  38  20  14  --   5  ...  868   99
# 1   Pyotr Kochetkov  20232024  CAR   L  36  34  19  12  --   3  ...  826   79
# 3      Lukas Dostal  20232024  ANA   L  34  28  10  19  --   1  ...  913  103
# 11  Arvid Soderblom  20232024  CHI   L  26  24   4  19  --   1  ...  659   93
# 2        Joel Hofer  20232024  STL   L  25  22  12  11  --   0  ...  647   61
# 5         Nico Daws  20232024  NJD   L  21  20   9  11  --   0  ...  508   60
# 6        Devon Levi  20232024  BUF   L  21  20   9   8  --   2  ...  540   64
# 7    Daniil Tarasov  20232024  CBJ   L  20  19   7   9  --   3  ...  590   63
#
#       Sv%   GAA      TOI SO  G  A  P  PIM
# 0   0.898  2.68  2220:14  3  0  0  0    2
# 1   0.913  2.36  2009:00  3  0  0  0    6
# 3   0.899  3.58  1724:28  0  0  0  0    6
# 11  0.877  4.02  1388:51  0  0  0  0    0
# 2   0.915  2.76  1326:45  1  0  0  0    2
# 5   0.894  3.15  1144:03  0  0  1  1    0
# 6   0.894  3.24  1184:40  0  0  0  0    0
# 7   0.904  3.20  1181:02  0  0  0  0    0
#
# [8 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import random

# 데이터프레임의 인덱스를 다시 설정
df1 = df1.reset_index(drop=True)

# 'Sv%' 열을 기준으로 데이터프레임을 역순으로 정렬
df1_sorted = df1.sort_values(by='Sv%', ascending=False)

# 연도와 해당 연도의 홈런 수 데이터
years = df1_sorted['Player']
home_runs = df1_sorted['Sv%']

# 그래프 크기 설정
plt.figure(figsize=(12, 6))

# 랜덤 색상 선택
def get_random_color():
    return "#" + ''.join([random.choice('0123456789ABCDEF') for i in range(6)])

# 그래프 그리기 (랜덤 색상 적용)
bars = plt.bar(years, home_runs, color=[get_random_color() for _ in range(len(years))])

plt.xlabel('Player')
plt.ylabel('Sv%')
plt.title('Sv%')

# 막대 위에 값 표시 (소수점으로)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}', ha='center', va='bottom')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import random

# 데이터프레임의 인덱스를 다시 설정
df1 = df1.reset_index(drop=True)

# 데이터프레임을 역순으로 정렬
df1 = df1.sort_values(by='GAA', ascending=False)

# 연도와 해당 연도의 홈런 수 데이터
years = df1['Player']
home_runs = df1['GAA']

# 그래프 크기 설정
plt.figure(figsize=(12, 6))

# 랜덤 색상 선택
def get_random_color():
    return "#" + ''.join([random.choice('0123456789ABCDEF') for i in range(6)])

# 그래프 그리기 (랜덤 색상 적용)
bars = plt.bar(years, home_runs, color=[get_random_color() for _ in range(len(years))])

plt.xlabel('Player')
plt.ylabel('GAA')
plt.title('GAA')

# 막대 위에 값 표시 (소수점으로)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}', ha='center', va='bottom')

plt.show()

# %%
df2 = pd.read_excel('Summary (2).xlsx')
df2
# Out:
#                 Player    Season     Team S/C Pos  GP   G   A   P  +/-  ...  \
# 0        Connor Bedard  20232024      CHI   R   C  55  21  33  54  -38  ...
# 1          Brock Faber  20232024      MIN   R   D  69   6  32  38    6  ...
# 2          Marco Rossi  20232024      MIN   L   C  69  18  17  35    3  ...
# 3          Luke Hughes  20232024      NJD   L   D  69   8  27  35  -19  ...
# 4     Luke Evangelista  20232024      NSH   R   R  67  15  17  32    2  ...
# 5         Logan Cooley  20232024      ARI   L   C  68  13  19  32  -13  ...
# 6      Dmitri Voronkov  20232024      CBJ   L   L  63  17  14  31    4  ...
# 7          Connor Zary  20232024      CGY   L   C  50  12  17  29   17  ...
# 8       Tyson Foerster  20232024      PHI   R   R  64  17  12  29    7  ...


# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 0 to 42
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  30 non-null     object
#  1   Season  30 non-null     int64
#  2   Team    30 non-null     object
#  3   S/C     30 non-null     object
#  4   Pos     30 non-null     object
#  5   GP      30 non-null     int64
#  6   G       30 non-null     int64
#  7   A       30 non-null     int64
#  8   P       30 non-null     int64
#  9   +/-     30 non-null     int64
#  10  PIM     30 non-null     int64
#  11  P/GP    30 non-null     float64
#  12  EVG     30 non-null     int64
#  13  EVP     30 non-null     int64
#  14  PPG     30 non-null     int64
#  15  PPP     30 non-null     int64
#  16  SHG     30 non-null     int64
#  17  SHP     30 non-null     int64
#  18  OTG     30 non-null     int64
#  19  GWG     30 non-null     int64
#  20  S       30 non-null     int64
#  21  S%      30 non-null     float64
#  22  TOI/GP  30 non-null     object
#  23  FOW%    30 non-null     object
# dtypes: float64(2), int64(16), object(6)
# memory usage: 5.9+ KB

# %%
df_sorted = df2.sort_values(by='P', ascending=False)
df2 = df_sorted
df2
# Out:
#                 Player    Season     Team S/C Pos  GP   G   A   P  +/-  ...  \
# 0        Connor Bedard  20232024      CHI   R   C  55  21  33  54  -38  ...
# 1          Brock Faber  20232024      MIN   R   D  69   6  32  38    6  ...
# 2          Marco Rossi  20232024      MIN   L   C  69  18  17  35    3  ...
# 3          Luke Hughes  20232024      NJD   L   D  69   8  27  35  -19  ...
# 4     Luke Evangelista  20232024      NSH   R   R  67  15  17  32    2  ...
# 5         Logan Cooley  20232024      ARI   L   C  68  13  19  32  -13  ...
# 6      Dmitri Voronkov  20232024      CBJ   L   L  63  17  14  31    4  ...
# 7          Connor Zary  20232024      CGY   L   C  50  12  17  29   17  ...
# 8       Tyson Foerster  20232024      PHI   R   R  64  17  12  29    7  ...
# 9        Adam Fantilli  20232024      CBJ   L   C  49  12  15  27  -21  ...
# 10       Matthew Knies  20232024      TOR   L   L  65  12  15  27    8  ...
# 11     Pavel Mintyukov  20232024      ANA   L   D  58   3  23  26  -19  ...
# 12        Leo Carlsson  20232024      ANA   L   C  42   9  15  24   -8  ...
# 13         Zach Benson  20232024      BUF   L   L  59   9  14  23   -1  ...
# 15     Alex Laferriere  20232024      LAK   R   R  67  11  11  22  -11  ...
# 14         Ridly Greig  20232024      OTT   L   C  57  10  12  22   14  ...
# 16         Bobby Brink  20232024      PHI   R   R  45   9  11  20    6  ...
# 17         Will Cuylle  20232024      NYR   L   L  69  12   8  20    4  ...
# 18         Simon Nemec  20232024      NJD   R   D  47   3  15  18   -2  ...
# 19     Martin Pospisil  20232024      CGY   L   C  49   7  10  17    7  ...
# 22          Tye Kartye  20232024      SEA   L   L  62   8   8  16   -5  ...
# 25    Scott Perunovich  20232024      STL   L   D  43   0  15  15   -3  ...
# 26  Michael Kesselring  20232024      ARI   R   D  51   5  10  15    5  ...
# 27     Jackson LaCombe  20232024      ANA   L   D  59   1  12  13  -26  ...
# 28    Kevin Korchinski  20232024      CHI   L   D  63   5   8  13  -34  ...
# 36        John Beecher  20232024      BOS   L   C  42   6   3   9   -5  ...
# 38     Nikita Okhotiuk  20232024  SJS,CGY   L   D  46   1   7   8  -22  ...
# 39         Jakub Lauko  20232024      BOS   L   C  50   2   6   8   -3  ...
# 41        Ryan Johnson  20232024      BUF   L   D  41   0   7   7    3  ...
# 42      Jayden Struble  20232024      MTL   L   D  44   3   4   7   -2  ...
#
#     PPG  PPP  SHG  SHP  OTG  GWG    S    S%  TOI/GP  FOW%
# 0     3   18    0    0    1    2  167  12.6   19:35  39.4
# 1     2   11    0    0    0    1  106   5.7   25:06    --
# 2     2    5    0    0    1    2  141  12.8   16:28    45
# 3     4   18    0    0    1    1  103   7.8   21:18    --
# 4     2    6    0    0    0    1  132  11.4   13:44    25
# 5     3   11    1    1    0    1  123  10.6   15:49  39.5
# 6     5    6    0    0    0    2  119  14.3   13:08  42.4
# 7     1    4    0    0    0    2   66  18.2   15:20  33.3
# 8     4    7    1    1    0    1  141  12.1   17:04     0
# 9     1    3    0    0    0    1  115  10.4   15:43  43.6
# 10    0    2    0    0    0    1   93  12.9   14:04     0
# 11    0    7    0    1    0    0   83   3.6   18:35    --
# 12    3    7    0    0    0    0   85  10.6   18:11  33.2
# 13    0    0    0    0    0    1   83  10.8   14:31  31.3
# 15    0    3    0    0    0    2  133   8.3   13:26  54.6
# 14    2    2    1    1    0    1   77  13.0   14:28  42.4
# 16    2    4    0    0    0    1   62  14.5   13:55    50
# 17    1    2    0    0    0    2  102  11.8   11:04    20
# 18    0    2    0    0    0    1   63   4.8   20:01    --
# 19    0    0    0    0    0    1   85   8.2   12:25    46
# 22    0    0    0    0    0    0   89   9.0   11:41  44.4
# 25    0    6    0    0    0    0   30   0.0   14:42    --
# 26    0    0    0    0    0    2   58   8.6   15:06    --
# 27    0    2    0    0    0    0   49   2.0   19:23    --
# 28    0    6    0    0    1    2   81   6.2   19:38    --
# 36    0    0    0    0    0    1   30  20.0   10:33  55.2
# 38    0    0    0    0    0    1   48   2.1   16:07    --
# 39    0    0    0    0    0    0   35   5.7    9:49    40
# 41    0    0    0    0    0    0   35   0.0   13:52    --
# 42    0    0    0    0    0    0   38   7.9   15:45    --
#
# [30 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import random

# 데이터프레임의 인덱스를 다시 설정
df2 = df2.reset_index(drop=True)

# 데이터프레임을 역순으로 정렬
df2 = df2.sort_values(by='P', ascending=False)

# 데이터프레임에서 상위 7개의 행만 선택
df2_top7 = df2.head(7)

# 연도와 해당 연도의 홈런 수 데이터
years = df2_top7['Player']
home_runs = df2_top7['P']

# 그래프 크기 설정
plt.figure(figsize=(10, 6))

# 랜덤 색상 선택
def get_random_color():
    return "#" + ''.join([random.choice('0123456789ABCDEF') for i in range(6)])

# 그래프 그리기 (랜덤 색상 적용)
bars = plt.bar(years, home_runs, color=[get_random_color() for _ in range(len(years))])

plt.xlabel('Player')
plt.ylabel('P')
plt.title('Player Points')

# 막대 위에 값 표시 (소수점 제거)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{int(height)}', ha='center', va='bottom')

plt.show()
